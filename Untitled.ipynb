# %% [markdown]
# # Bike Sharing Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
import seaborn as sns
import pyod

# %matplotlib inline

# %%
df = pd.read_csv("./data/hour.csv")
df2 = pd.read_csv("./data/day.csv")

# %%
df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
df2.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
df.isnull().values.any()
# Out:
# False

# %%
df2.isnull().values.any()
# Out:
# False

# %%
columns_combinations = [["instant", "temp"], ["instant", "hum"], ["instant", "windspeed"], ["instant", "temp"], ["instant", "cnt"], ]

for combination in columns_combinations:

    figure = plt.figure
    ax = plt.gca()
    ax.scatter(df2[combination[0]],df2[combination[1]],c='b')
    ax.set_xlabel(combination[0])
    ax.set_ylabel(combination[1])
    ax.set_title("{} as a function of {}".format(combination[1], combination[0]))

    plt.show()

# %%
columns_combinations = [["instant", "cnt"], ]
weekdays = [0, 1, 2, 3, 4, 5, 6]
weekday_id = np.array(df2["weekday"])

for combination in columns_combinations:


    for weekday in weekdays:
        figure = plt.figure
        ax = plt.gca()
        ax.plot(df2[combination[0]][weekday_id==weekday],df2[combination[1]][weekday_id==weekday],c='b')
        ax.set_xlabel(combination[0])
        ax.set_ylabel(combination[1])
        ax.set_title("{} as a function of {} in weekday no. {}".format(combination[1], combination[0], weekday))

        plt.show()

# %%
plt.hist(df2['cnt'], bins=100)
plt.ylabel('Bikes in daily use')
plt.show()
print("Average number of bikes in use is {} \nMedian of number of bikes in use is".format(df2['cnt'].mean()), df2['cnt'].median())
# Out:
# Average number of bikes in use is 4504.3488372093025
# Median of number of bikes in use is 4548.0

# %%
plt.hist(df['cnt'], bins=100)
plt.ylabel('Bikes in hourly use')
plt.show()
print("Average number of bikes in use is {} \nMedian of number of bikes in use is".format(df['cnt'].mean()), df['cnt'].median())
# Out:
# Average number of bikes in use is 189.46308763450142
# Median of number of bikes in use is 142.0

# %%
daily_averages = []
daily_medians = []
for weekday in weekdays:
    daily_averages.append(df2['cnt'][weekday_id==weekday].mean())
    daily_medians.append(df2['cnt'][weekday_id==weekday].median())
print(daily_averages)
print(daily_medians)
# Out:
# [4228.828571428571, 4338.1238095238095, 4510.663461538462, 4548.538461538462, 4667.259615384615, 4690.288461538462, 4550.542857142857]
# [4334.0, 4359.0, 4576.5, 4642.5, 4721.0, 4601.5, 4521.0]

# %% [markdown]
# ## Molding data

# %%
del df["instant"]
del df["dteday"]
del df["casual"]
del df["registered"]
del df["temp"]
del df["season"]

# %%
df
# Out:
#        yr  mnth  hr  holiday  weekday  workingday  weathersit   atemp   hum  \
# 0       0     1   0        0        6           0           1  0.2879  0.81
# 1       0     1   1        0        6           0           1  0.2727  0.80
# 2       0     1   2        0        6           0           1  0.2727  0.80
# 3       0     1   3        0        6           0           1  0.2879  0.75
# 4       0     1   4        0        6           0           1  0.2879  0.75
# ...    ..   ...  ..      ...      ...         ...         ...     ...   ...
# 17374   1    12  19        0        1           1           2  0.2576  0.60
# 17375   1    12  20        0        1           1           2  0.2576  0.60
# 17376   1    12  21        0        1           1           1  0.2576  0.60
# 17377   1    12  22        0        1           1           1  0.2727  0.56
# 17378   1    12  23        0        1           1           1  0.2727  0.65
#
#        windspeed  cnt
# 0         0.0000   16
# 1         0.0000   40
# 2         0.0000   32
# 3         0.0000   13
# 4         0.0000    1
# ...          ...  ...
# 17374     0.1642  119
# 17375     0.1642   89
# 17376     0.1642   90
# 17377     0.1343   61
# 17378     0.1343   49
#
# [17379 rows x 11 columns]

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True) # df.corr() makes a correlation matrix, sns.heatmap creates heatmap of values
plt.show()

# %%
num_obs = len(df)
num_first_year = len(df.loc[df["yr"] == 0])
num_second_year = len(df.loc[df["yr"] == 1])
print("Number of instances in the first year:  {0} ({1:2.2f}%)".format(num_first_year, (num_first_year/num_obs) * 100))
print("Number of instances in the second year: {0} ({1:2.2f}%)".format(num_second_year, (num_second_year/num_obs) * 100))
# Out:
# Number of instances in the first year:  8645 (49.74%)
# Number of instances in the second year: 8734 (50.26%)

# %%
from sklearn.model_selection import train_test_split
feature_col_names = ["yr", "mnth", "hr", "holiday", "weekday", "workingday", "weathersit", "atemp", "hum", "windspeed"]
predicted_class_names = ["cnt"]

X = df[feature_col_names].values     # predictor feature columns 
y = df[predicted_class_names].values # predicted class (1=true, 0=false) column

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=40)

# %%
print("Original first year  : {0} ({1:0.2f}%)".format(len(df.loc[df["yr"] == 0]), (len(df.loc[df["yr"] == 0])/len(df.index)) * 100.0))
print("Original second year : {0} ({1:0.2f}%)".format(len(df.loc[df["yr"] == 1]), (len(df.loc[df["yr"] == 1])/len(df.index)) * 100.0))
print("")
print("Training first year  : {0} ({1:0.2f}%)".format(len(X_train[X_train[:, 0] == 0]), (len(X_train[X_train[:, 0] == 0])/len(X_train) * 100.0)))
print("Training second year : {0} ({1:0.2f}%)".format(len(X_train[X_train[:, 0] == 1]), (len(X_train[X_train[:, 0] == 1])/len(X_train) * 100.0)))
print("")
print("Test first year      : {0} ({1:0.2f}%)".format(len(X_test[X_test[:, 0] == 0]), (len(X_test[X_test[:, 0] == 0])/len(X_test) * 100.0)))
print("Test second year     : {0} ({1:0.2f}%)".format(len(X_test[X_test[:, 0] == 1]), (len(X_test[X_test[:, 0] == 1])/len(X_test) * 100.0)))
# Out:
# Original first year  : 8645 (49.74%)
# Original second year : 8734 (50.26%)
#
# Training first year  : 5194 (49.81%)
# Training second year : 5233 (50.19%)
#
# Test first year      : 3451 (49.64%)
# Test second year     : 3501 (50.36%)

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# create Gaussian Naive Bayes model object and train it with the data
nb_model = GaussianNB()

nb_model.fit(X_train, y_train.ravel())
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
from sklearn import metrics

# predict values using the training data
nb_predict_train = nb_model.predict(X_test)

print(len(y_test))
len(nb_predict_train)
# Out:
# 6952
# 6952

# %%
x=np.arange(len(X_test))
figure = plt.figure
ax = plt.gca()
ax.plot(x,nb_predict_train,c='b')
ax.plot(x, y_test, c='r')
ax.set_xlabel(combination[0])
ax.set_ylabel(combination[1])
ax.set_title("{} as a function of {}".format(combination[1], combination[0]))
# Out:
# Text(0.5, 1.0, 'cnt as a function of instant')
